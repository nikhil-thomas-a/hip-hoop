# %% [markdown]
# # 01 · Data Collection
# Fetches NBA game logs and Genius lyrics metadata for all 110 mentions.
#
# **Run time:** ~15–25 minutes (API rate limits).
#
# Prerequisites:
# ```
# pip install -r requirements.txt
# cp .env.example .env  # then add your GENIUS_API_KEY
# ```

# %%
import sys
sys.path.insert(0, '..')
from src.fetch_gamelogs import fetch_all as fetch_games
from src.fetch_lyrics import fetch_all as fetch_lyrics
import pandas as pd

mentions = pd.read_csv('../data/raw/mentions.csv')
print(f"Loaded {len(mentions)} mentions across {mentions['player'].nunique()} unique players")
mentions.head()
# Out:
# Loaded 110 mentions across 92 unique players
#    mention_id            player player_id_bref            artist  \
# 0           1      LeBron James      jamesle01             Drake
# 1           2       Kobe Bryant      bryanko01         Lil Wayne
# 2           3  Shaquille O'Neal      onealsh01  Notorious B.I.G.
# 3           4     Allen Iverson      iversal01             Jay-Z
# 4           5      Kevin Durant      duranke01    Kendrick Lamar
#
#                  song                        album release_date mention_type  \
# 0             Forever              Relapse: Refill   2009-08-13   compliment
# 1         Kobe Bryant                  No Ceilings   2009-11-16   compliment
# 2            The What                 Ready to Die   1994-09-13   compliment
# 3           Hovi Baby  The Dynasty: Roc La Familia   2000-10-31   compliment
# 4  Backseat Freestyle        good kid m.A.A.d city   2012-10-22      neutral
#
#                                                lyric  artist_tier  \
# 0  That's why they call me Young Money LeBron Jam...          2.8
# 1  Call me Kobe Bryant cause I'm ballin' every night          2.5
# 2     I'm catchin' bodies like Shaq catch alley-oops          3.0
# 3          Flow butter smooth like Iverson crossover          3.0
# 4               Got K.D. numbers scoring every night          2.9
#
#   player_position    era
# 0              SF  2000s
# 1              SG  2000s
# 2               C  1990s
# 3              PG  2000s
# 4              SF  2010s

# %%
# Fetch NBA game logs (nba_api)
# This hits NBA's API — be patient, it takes a few minutes
# Already-fetched players are skipped automatically
fetch_games('../data/raw/mentions.csv')
# Out:
# Fetching game logs for 92 unique players...
#   0%|                                                                                           | 0/92 [00:00<?, ?it/s]
#   ↩ Skipping LeBron James (already fetched)
#   ↩ Skipping Kobe Bryant (already fetched)
#   ↩ Skipping Shaquille O'Neal (already fetched)
#   ↩ Skipping Allen Iverson (already fetched)
#   ↩ Skipping Kevin Durant (already fetched)
#   ↩ Skipping Patrick Ewing (already fetched)
#   ↩ Skipping Michael Jordan (already fetched)
#   ↩ Skipping Gary Payton (already fetched)
#   ↩ Skipping Vince Carter (already fetched)
#   ↩ Skipping Tim Duncan (already fetched)
#   ↩ Skipping Dwyane Wade (already fetched)
#   ↩ Skipping Chris Paul (already fetched)
#   ↩ Skipping Kevin Garnett (already fetched)
#   ↩ Skipping James Harden (already fetched)
#   ↩ Skipping Stephen Curry (already fetched)
#   ↩ Skipping Kyrie Irving (already fetched)
#   ↩ Skipping Giannis Antetokounmpo (already fetched)
#   → Fetching Luka Doncic...
#   ✗ Could not find NBA API ID for: Luka Doncic
#   ✗ No data for Luka Doncic
#  20%|████████████████                                                                  | 18/92 [00:00<00:02, 35.35it/s]
#   ↩ Skipping Ja Morant (already fetched)
#   ↩ Skipping Dwight Howard (already fetched)
#   ↩ Skipping Russell Westbrook (already fetched)
#   ↩ Skipping Carmelo Anthony (already fetched)
#   ↩ Skipping Derrick Rose (already fetched)
#   ↩ Skipping Baron Davis (already fetched)
#   → Fetching Penny Hardaway...
#   ✗ Could not find NBA API ID for: Penny Hardaway
#   ✗ No data for Penny Hardaway
#  27%|██████████████████████▎                                                           | 25/92 [00:01<00:02, 22.57it/s]
#   ↩ Skipping Stephon Marbury (already fetched)
#   ↩ Skipping Tracy McGrady (already fetched)
#   ↩ Skipping Paul Pierce (already fetched)
#   ↩ Skipping Yao Ming (already fetched)
#   ↩ Skipping Jason Kidd (already fetched)
#   ↩ Skipping Steve Nash (already fetched)
#   ↩ Skipping Dirk Nowitzki (already fetched)
#   ↩ Skipping Ray Allen (already fetched)
#   → Fetching Amare Stoudemire...
#   ✗ Could not find NBA API ID for: Amare Stoudemire
#   ✗ No data for Amare Stoudemire
#  37%|██████████████████████████████▎                                                   | 34/92 [00:01<00:02, 20.34it/s]
#   ↩ Skipping Chauncey Billups (already fetched)
#   ↩ Skipping Gilbert Arenas (already fetched)
#   ↩ Skipping Paul George (already fetched)
#   ↩ Skipping Kawhi Leonard (already fetched)
#   ↩ Skipping Joel Embiid (already fetched)
#   ↩ Skipping Zion Williamson (already fetched)
#   → Fetching Nikola Jokic...
#   ✗ Could not find NBA API ID for: Nikola Jokic
#   ✗ No data for Nikola Jokic
#  45%|████████████████████████████████████▌                                             | 41/92 [00:02<00:02, 17.76it/s]
#   ↩ Skipping Damian Lillard (already fetched)
#   ↩ Skipping Klay Thompson (already fetched)
#   ↩ Skipping Draymond Green (already fetched)
#   ↩ Skipping Anthony Davis (already fetched)
#   ↩ Skipping Karl-Anthony Towns (already fetched)
#   ↩ Skipping Ben Simmons (already fetched)
#   ↩ Skipping Lonzo Ball (already fetched)
#   → Fetching De'Aaron Fox...
#   ✗ No data for De'Aaron Fox
#  53%|███████████████████████████████████████████▋                                      | 49/92 [00:05<00:08,  5.12it/s]
#   ↩ Skipping Trae Young (already fetched)
#   ↩ Skipping Devin Booker (already fetched)
#   ↩ Skipping Bradley Beal (already fetched)
#   ↩ Skipping Kemba Walker (already fetched)
#   → Fetching Donovan Mitchell...
#   ✗ No data for Donovan Mitchell
#  59%|████████████████████████████████████████████████▏                                 | 54/92 [00:08<00:10,  3.77it/s]
#   ↩ Skipping Bam Adebayo (already fetched)
#   ↩ Skipping Victor Oladipo (already fetched)
#   → Fetching Domantas Sabonis...
#   ✗ No data for Domantas Sabonis
#  62%|██████████████████████████████████████████████████▊                               | 57/92 [00:10<00:12,  2.79it/s]
#   ↩ Skipping CJ McCollum (already fetched)
#   ↩ Skipping Hassan Whiteside (already fetched)
#   ↩ Skipping Andre Drummond (already fetched)
#   ↩ Skipping Dennis Rodman (already fetched)
#   ↩ Skipping Scottie Pippen (already fetched)
#   ↩ Skipping Charles Barkley (already fetched)
#   ↩ Skipping Reggie Miller (already fetched)
#   ↩ Skipping John Stockton (already fetched)
#   ↩ Skipping Karl Malone (already fetched)
#   ↩ Skipping Grant Hill (already fetched)
#   ↩ Skipping Chris Webber (already fetched)
#   ↩ Skipping Anfernee Hardaway (already fetched)
#   ↩ Skipping Kevin Johnson (already fetched)
#   ↩ Skipping Hakeem Olajuwon (already fetched)
#   ↩ Skipping David Robinson (already fetched)
#   ↩ Skipping Alonzo Mourning (already fetched)
#   ↩ Skipping Latrell Sprewell (already fetched)
#   ↩ Skipping Mitch Richmond (already fetched)
#   ↩ Skipping Muggsy Bogues (already fetched)
#   ↩ Skipping Shawn Kemp (already fetched)
#   ↩ Skipping Nick Van Exel (already fetched)
#   ↩ Skipping Glen Rice (already fetched)
#   ↩ Skipping Blake Griffin (already fetched)
#   → Fetching Jimmy Butler...
#   ✗ No data for Jimmy Butler
#  88%|████████████████████████████████████████████████████████████████████████▏         | 81/92 [00:13<00:02,  5.19it/s]
#   ↩ Skipping Jayson Tatum (already fetched)
#   ↩ Skipping Jaylen Brown (already fetched)
#   ↩ Skipping Khris Middleton (already fetched)
#   ↩ Skipping Fred VanVleet (already fetched)
#   → Fetching Pascal Siakam...
#   ✗ No data for Pascal Siakam
#  93%|████████████████████████████████████████████████████████████████████████████▋     | 86/92 [00:15<00:01,  4.12it/s]
#   → Fetching Scottie Barnes...
#   ✗ No data for Scottie Barnes
#  95%|█████████████████████████████████████████████████████████████████████████████▌    | 87/92 [00:18<00:01,  2.93it/s]
#   → Fetching Cade Cunningham...
#   ✗ No data for Cade Cunningham
#  96%|██████████████████████████████████████████████████████████████████████████████▍   | 88/92 [00:20<00:01,  2.14it/s]
#   ↩ Skipping Evan Mobley (already fetched)
#   → Fetching Jalen Green...
#   ✗ No data for Jalen Green
#  98%|████████████████████████████████████████████████████████████████████████████████▏ | 90/92 [00:23<00:01,  1.72it/s]
#   → Fetching Anthony Edwards...
#   ✗ No data for Anthony Edwards
#  99%|█████████████████████████████████████████████████████████████████████████████████ | 91/92 [00:25<00:00,  1.32it/s]
#   → Fetching LaMelo Ball...
#   ✗ No data for LaMelo Ball
# 100%|██████████████████████████████████████████████████████████████████████████████████| 92/92 [00:29<00:00,  3.10it/s]
# Done fetching game logs.

# %%
# Verify game logs downloaded
import os
log_dir = '../data/raw/game_logs'
logs = os.listdir(log_dir)
print(f"Game logs fetched: {len(logs)}")
print("\n".join(sorted(logs)[:10]), "...")
# Out:
# Game logs fetched: 78
# allen_iverson.csv
# alonzo_mourning.csv
# andre_drummond.csv
# anfernee_hardaway.csv
# anthony_davis.csv
# bam_adebayo.csv
# baron_davis.csv
# ben_simmons.csv
# blake_griffin.csv
# bradley_beal.csv ...

# %%
# Fetch Genius lyrics metadata
# Requires GENIUS_API_KEY in .env
fetch_lyrics('../data/raw/mentions.csv')
# Out:
# Fetching lyrics for 110 songs...
#
#   ↩ Drake — Forever (cached)
#   ↩ Lil Wayne — Kobe Bryant (cached)
#   ↩ Notorious B.I.G. — The What (cached)
#   ↩ Jay-Z — Hovi Baby (cached)
#   ↩ Kendrick Lamar — Backseat Freestyle (cached)
#   ↩ Notorious B.I.G. — One More Chance (cached)
#   ↩ Jay-Z — Public Service Announcement (cached)
#   ↩ Jay-Z — D'Evils (cached)
#   ↩ Ludacris — Saturday (Oooh Ooooh!) (cached)
#   ↩ Common — The Food (cached)
#   ↩ Kanye West — Champion (cached)
#   ↩ Drake — Miss Me (cached)
#   ↩ Jay-Z — Kingdom Come (cached)
#   ↩ Travis Scott — Goosebumps (cached)
#   ↩ Drake — God's Plan (cached)
#   ↩ J. Cole — Apparently (cached)
#   ↩ Pusha T — Santeria (cached)
#   ↩ Drake — Champagne Poetry (cached)
#   ↩ Young Thug — Ski (cached)
#   ↩ Lil Wayne — Right Above It (cached)
#   → Meek Mill — Cold Hearted II
#   ✗ Not found on Genius
#   ↩ Fabolous — Breathe (cached)
#   ↩ Chance the Rapper — Paranoia (cached)
#   ↩ E-40 — Tell Me When to Go (cached)
#   ↩ Nas — Street Dreams (cached)
#   ↩ Cam'ron — Dipset Anthem (cached)
#   ↩ Lil Wayne — Mr. Carter (cached)
#   ↩ Jay-Z — Encore (cached)
#   ↩ Kanye West — Gone (cached)
#   ↩ Jay-Z — Takeover (cached)
#   ↩ Lil Wayne — A Milli (cached)
#   ↩ Drake — Successful (cached)
#   ↩ Jay-Z — Blueprint 2 (cached)
#   ↩ Kanye West — All Falls Down (cached)
#   ↩ Eminem — Lose Yourself (cached)
#   ↩ Lil Wayne — Lollipop (cached)
#   ↩ Drake — Energy (cached)
#   ↩ Kendrick Lamar — HUMBLE. (cached)
#   ↩ Meek Mill — Dangerous (cached)
#   ↩ Drake — Laugh Now Cry Later (cached)
#   ↩ J. Cole — p r i d e . i s . t h e . d e v i l (cached)
#   ↩ Common — HER Love (cached)
#   ↩ Drake — Trophies (cached)
#   ↩ Kendrick Lamar — DNA. (cached)
#   ↩ Drake — Forever (cached)
#   ↩ Migos — Bad and Boujee (cached)
#   ↩ Meek Mill — Going Bad (cached)
#   ↩ Drake — God's Plan (cached)
#   ↩ Kendrick Lamar — Alright (cached)
#   ↩ Lil Baby — The Bigger Picture (cached)
#   ↩ Drake — TSU (cached)
#   ↩ J. Cole — Fire Squad (cached)
#   ↩ Drake — Know Yourself (cached)
#   ↩ Jay-Z — Smile (cached)
#   ↩ Rick Ross — BIG TYME (cached)
#   ↩ Future — Mask Off (cached)
#   ↩ 2 Chainz — Momma I Hit a Lick (cached)
#   ↩ Chance the Rapper — Blessings (cached)
#   ↩ Rick Ross — Sanctified (cached)
#   ↩ Big Sean — One Man Can Change the World (cached)
#   ↩ Notorious B.I.G. — Big Poppa (cached)
#   ↩ Jay-Z — Song Cry (cached)
#   ↩ Ice Cube — Check Yo Self (cached)
#   ↩ Jay-Z — 99 Problems (cached)
#   ↩ Dr. Dre — The Next Episode (cached)
#   ↩ Dr. Dre — Still D.R.E. (cached)
#   ↩ Outkast — Ms. Jackson (cached)
#   ↩ DMX — Ruff Ryders Anthem (cached)
#   ↩ Tupac — Picture Me Rollin (cached)
#   ↩ Ice Cube — It Was a Good Day (cached)
#   ↩ Notorious B.I.G. — Juicy (cached)
#   ↩ Tupac — California Love (cached)
#   ↩ Jay-Z — Can I Get A... (cached)
#   ↩ Nas — Hate Me Now (cached)
#   ↩ Snoop Dogg — Gin and Juice (cached)
#   ↩ Too Short — Gettin It (cached)
#   ↩ Method Man — All I Need (cached)
#   ↩ Sir Mix-a-Lot — Baby Got Back (cached)
#   ↩ Snoop Dogg — Murder Was the Case (cached)
#   ↩ 2Pac — How Do U Want It (cached)
#   ↩ Jay-Z — Crown (cached)
#   ↩ Drake — The Language (cached)
#   ↩ Jay-Z — Dirt Off Your Shoulder (cached)
#   ↩ Lil Wayne — Got Money (cached)
#   ↩ Jay-Z — Empire State of Mind (cached)
#   ↩ Kendrick Lamar — Swimming Pools (cached)
#   ↩ Kanye West — Gorgeous (cached)
#   ↩ Meek Mill — Rosé Red (cached)
#   ↩ J. Cole — Love Yourz (cached)
#   ↩ Drake — In My Feelings (cached)
#   ↩ Meek Mill — Ima Boss (cached)
#   ↩ Drake — What's Next (cached)
#   ↩ J. Cole — KOD (cached)
#   ↩ Big Sean — Bounce Back (cached)
#   ↩ Drake — Chicago Freestyle (cached)
#   ↩ Drake — From Time (cached)
#   ↩ Lil Baby — Days Of Our Lives (cached)
#   ↩ Drake — Fair Trade (cached)
#   ↩ J. Cole — let go my hand (cached)
#   ↩ Pusha T — Diet Coke (cached)
#   ↩ Travis Scott — ESCAPE PLAN (cached)
#   ↩ Drake — TSU (cached)
#   ↩ Young Thug — Digits (cached)
#   ↩ Jay-Z — Otis (cached)
#   ↩ Eminem — Without Me (cached)
#   ↩ Jay-Z — Song Cry (cached)
#   ↩ Nas — Made You Look (cached)
#   ↩ Jay-Z — U Don't Know (cached)
#   ↩ J. Cole — Love Yourz (cached)
#   ↩ Drake — Nonstop (cached)
#
# Saved lyrics metadata to D:\Codes\hip-hoop\notebooks\..\data\raw\lyrics_meta.csv
#      mention_id                song            artist  \
# 0             1             Forever             Drake
# 1             2         Kobe Bryant         Lil Wayne
# 2             3            The What  Notorious B.I.G.
# 3             4           Hovi Baby             Jay-Z
# 4             5  Backseat Freestyle    Kendrick Lamar
# ..          ...                 ...               ...
# 105         106            Song Cry             Jay-Z
# 106         107       Made You Look               Nas
# 107         108        U Don't Know             Jay-Z
# 108         109          Love Yourz           J. Cole
# 109         110             Nonstop             Drake
#
#                                          lyric_snippet  full_lyrics_available  \
# 0    That's why they call me Young Money LeBron Jam...                   True
# 1    Call me Kobe Bryant cause I'm ballin' every night                   True
# 2       I'm catchin' bodies like Shaq catch alley-oops                   True
# 3            Flow butter smooth like Iverson crossover                   True
# 4                 Got K.D. numbers scoring every night                   True
# ..                                                 ...                    ...
# 105  Duncan consistency night in night out you know...                   True
# 106  AI crossover I leave defenders on the floor re...                   True
# 107  Shaq dominant I back you down until there's no...                   True
# 108  Curry range I shoot from places that shouldn't...                   True
# 109  Giannis nonstop I don't need a jumper I just g...                   True
#
#      lyrics_length                                                url
# 0             5531  https://genius.com/Drake-kanye-west-lil-wayne-...
# 1             4254    https://genius.com/Lil-wayne-kobe-bryant-lyrics
# 2             3535  https://genius.com/The-notorious-big-the-what-...
# 3             3856          https://genius.com/Jay-z-hovi-baby-lyrics
# 4             2881  https://genius.com/Kendrick-lamar-backseat-fre...
# ..             ...                                                ...
# 105           3415           https://genius.com/Jay-z-song-cry-lyrics
# 106           2992        https://genius.com/Nas-made-you-look-lyrics
# 107           2570        https://genius.com/Jay-z-u-dont-know-lyrics
# 108           2983        https://genius.com/J-cole-love-yourz-lyrics
# 109           3551            https://genius.com/Drake-nonstop-lyrics
#
# [110 rows x 7 columns]

# %%
# Quick sanity check on a single game log
import pandas as pd
sample = pd.read_csv('../data/raw/game_logs/lebron_james.csv')
print(f"LeBron game log: {len(sample)} games")
print(sample[['GAME_DATE', 'PTS', 'AST', 'REB', 'SEASON']].head(10))
# Out:
# LeBron game log: 306 games
#       GAME_DATE  PTS  AST  REB   SEASON
# 0  Apr 09, 2017   32   10   16  2016-17
# 1  Apr 07, 2017   27    7    8  2016-17
# 2  Apr 05, 2017   36    6   10  2016-17
# 3  Apr 04, 2017   18   11   11  2016-17
# 4  Apr 02, 2017   41   11   14  2016-17
# 5  Mar 31, 2017   34    6    9  2016-17
# 6  Mar 30, 2017   26    8   10  2016-17
# 7  Mar 27, 2017   17    8    8  2016-17
# 8  Mar 25, 2017   24    8   11  2016-17
# 9  Mar 24, 2017   32   11    9  2016-17
