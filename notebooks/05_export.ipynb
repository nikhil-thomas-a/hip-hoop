# %% [markdown]
# # 05 · Export
# Generates `data/processed/results.json` — the single file consumed by `index.html`.
#
# Run this after all previous notebooks are complete.

# %%
import sys
sys.path.insert(0, '..')
from src.export import build_export
import json
from pathlib import Path

results = build_export()
print("\n── KEY FINDINGS ──────────────────────────────────────")
for k, v in results['key_findings'].items():
    print(f"  {k}: {v}")
# Out:
# Exporting 140 total mentions, 140 with complete data...
#
# ✓ results.json written to D:\Codes\hip-hoop\notebooks\..\data\processed\results.json
#   140 mention records
#   Key findings: {'avg_pts_delta_30g': 0.5, 'avg_ast_delta_30g': 0.05, 'avg_reb_delta_30g': 0.27, 'pct_positive_impact': 60.0, 'n_total': 140, 'n_analyzed': 140, 'n_compliment': 84, 'n_diss': 8, 'n_neutral': 48}
#
# ── KEY FINDINGS ──────────────────────────────────────
#   avg_pts_delta_30g: 0.5
#   avg_ast_delta_30g: 0.05
#   avg_reb_delta_30g: 0.27
#   pct_positive_impact: 60.0
#   n_total: 140
#   n_analyzed: 140
#   n_compliment: 84
#   n_diss: 8
#   n_neutral: 48

# %%
# Verify the JSON is valid and readable
with open('../data/processed/results.json') as f:
    check = json.load(f)
print(f"✓ results.json is valid JSON")
print(f"  Mentions: {len(check['mentions'])}")
print(f"  Top impacts: {len(check['top_impacts'])}")
print(f"  Generated at: {check['generated_at']}")
# Out:
# ✓ results.json is valid JSON
#   Mentions: 140
#   Top impacts: 10
#   Generated at: 2026-04-07T12:55:36.205913

# %%
# Preview top 5 impacts
print("\n── TOP 5 IMPACTS ─────────────────────────────────────")
for m in check['top_impacts'][:5]:
    d = m['deltas']
    print(f"  {m['player']} × {m['artist']} ({m['era']}, {m['mention_type']})")
    print(f"    ΔPTS={d['pts_30g']:+}  ΔAST={d['ast_30g']:+}  ΔREB={d['reb_30g']:+}  Composite={d['composite_30g']:+}")
    print()
# Out:
# ── TOP 5 IMPACTS ─────────────────────────────────────
#   Kevin Johnson × Ice Cube (1990s, neutral)
#     ΔPTS=-6.77  ΔAST=-5.04  ΔREB=-1.78  Composite=-4.754
#
#   Amare Stoudemire × Kanye West (2000s, neutral)
#     ΔPTS=+9.4  ΔAST=+0.76  ΔREB=+1.83  Composite=+4.537
#
#   Victor Oladipo × Future (2010s, compliment)
#     ΔPTS=+9.3  ΔAST=+1.26  ΔREB=+0.94  Composite=+4.38
#
#   Russell Westbrook × Meek Mill (2010s, diss)
#     ΔPTS=+9.1  ΔAST=-0.5  ΔREB=+2.03  Composite=+4.099
#
#   Derrick Rose × Chance the Rapper (2010s, compliment)
#     ΔPTS=-6.67  ΔAST=-3.4  ΔREB=-0.07  Composite=-3.709

# %%
# Check file size — results.json should be < 2MB for GitHub Pages
import os
size_kb = os.path.getsize('../data/processed/results.json') / 1024
print(f"results.json size: {size_kb:.1f} KB")
if size_kb > 1000:
    print("⚠ File is large — consider minifying before committing")
else:
    print("✓ Size is fine for GitHub Pages")
print("\n✓ All done! Open index.html in your browser to see the dashboard.")
# Out:
# results.json size: 179.9 KB
# ✓ Size is fine for GitHub Pages
#
# ✓ All done! Open index.html in your browser to see the dashboard.
